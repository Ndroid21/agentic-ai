# %%
# !!pip install litellm -q
# Out:
# []

# %%
import os
from google.colab import userdata
api_key = userdata.get('GEMINI_API_KEY')
os.environ['GEMINI_API_KEY'] = api_key

# %%
from litellm import completion
from typing import List, Dict


def generate_response(messages: List[Dict]) -> str:
    """Call LLM to get response"""
    response = completion(
        model="gemini/gemini-3.1-flash-lite",
        messages=messages,
        max_tokens=1024
    )
    return response.choices[0].message.content


messages = [
    {"role": "system", "content": "You are an expert software engineer that prefers functional programming."},
    {"role": "user", "content": "Write a function to swap the keys and values in a dictionary."}
]

response = generate_response(messages)
print(response)
# Out:
# In a functional approach, we treat the dictionary as a collection of entries that we transform into a new structure. In Python, this is best achieved using a dictionary comprehension.
#
# ### The Implementation
#
# ```python
# def invert_dict(d: dict) -> dict:
#     """
#     Swaps the keys and values of a dictionary.
#
#     Assumes that all values in the original dictionary are hashable
#     and unique (or that you intend for the last key to overwrite
#     previous ones if values are duplicated).
#     """
#     return {value: key for key, value in d.items()}
# ```
#
# ### Why this follows functional principles:
#
# 1.  **Immutability**: This function does not modify the input dictionary `d`. Instead, it creates and returns a brand new dictionary, adhering to the principle of pure functions (no side effects).
# 2.  **Declarative Syntax**: The dictionary comprehension describes *what* the result should look like, rather than outlining the imperative steps (creating an empty dict, looping, inserting items) required to build it.
# 3.  **Conciseness**: It maps the input data directly to the output structure in a single, readable expression.
#
# ### A Note on Safety (Functional "Safe" Alternative)
# If you suspect the values in your dictionary might be **non-hashable** (like lists) or **not unique**, a more robust functional approach might be to use `dict.fromkeys` or handle collisions explicitly to ensure no data is silently lost:
#
# ```python
# from collections import defaultdict
#
# def invert_dict_safe(d: dict) -> dict:
#     """
#     Handles potential duplicate values by grouping keys into a list.
#     """
#     inverted = defaultdict(list)
#     for k, v in d.items():
#         inverted[v].append(k)
#     return dict(inverted)
# ```
#
# This version is safer because it guarantees that even if multiple keys share the same value, you won't lose information during the inversion.
